# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import time

# Para usar o vídeo
#cap = cv2.VideoCapture('hall_box_battery_mp2.mp4')

# As 3 próximas linhas são para usar a webcam
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
kernel = np.ones((3,3),np.uint8)
#k = 1/205484760


def identifica_cor(frame):
    '''
    Segmenta o maior objeto cuja cor é parecida com cor_h (HUE da cor, no espaço HSV).
    '''

    # No OpenCV, o canal H vai de 0 até 179, logo cores similares ao 
    # vermelho puro (H=0) estão entre H=-8 e H=8. 
    # Veja se este intervalo de cores está bom
    frame_hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    cor_menor = np.array([-6, 100, 100])
    cor_maior = np.array([14, 255, 255])
    segmentado_cor = cv2.inRange(frame_hsv, cor_menor, cor_maior)

    # Será possível limpar a imagem segmentado_cor? 
    # Pesquise: https://docs.opencv.org/trunk/d9/d61/tutorial_py_morphological_ops.html
    opening = cv2.morphologyEx(segmentado_cor, cv2.MORPH_OPEN, kernel)
    #closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
    #dilation = cv2.dilate(closing,kernel,iterations = 1)
    erosion = cv2.erode(opening,kernel,iterations = 1)
    #closing = cv2.morphologyEx(erosion, cv2.MORPH_CLOSE, kernel)
    # Encontramos os contornos na máscara e selecionamos o de maior área
    #img_out, contornos, arvore = cv2.findContours(segmentado_cor.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) 
    img_out, contornos, arvore = cv2.findContours(erosion.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) 
    maior_contorno = None
    maior_contorno_area = 0


    cv2.drawContours(frame, contornos, -1, [255, 0, 255], 5)


    for cnt in contornos:
        area = cv2.contourArea(cnt)


        if area > maior_contorno_area:
            maior_contorno = cnt
            maior_contorno_area = area
    #print(maior_contorno[0])
    distance = (((2009**2)*474.5)/maior_contorno_area)**(1/2)
    print("Distância é: {0}".format(distance))
    
    
    # Encontramos o centro do contorno fazendo a média de todos seus pontos.
    if not maior_contorno is None :
        cv2.drawContours(frame, [maior_contorno], -1, [0, 0, 255], 5)
        maior_contorno = np.reshape(maior_contorno, (maior_contorno.shape[0], 2))
        media = maior_contorno.mean(axis=0)
        media = media.astype(np.int32)
        cv2.circle(frame, tuple(media), 5, [0, 255, 0])
    else:
        media = (0, 0)

    cv2.imshow('', frame)
    cv2.imshow('imagem in_range', erosion)
    cv2.waitKey(1)

    centro = (frame.shape[0]//2, frame.shape[1]//2)

    return media, centro


while(True):
    # Capture frame-by-frame
    print("Novo frame")
    ret, frame = cap.read()


    img = frame.copy()

    media, centro = identifica_cor(img)

    #More drawing functions @ http://docs.opencv.org/2.4/modules/core/doc/drawing_functions.html
    # Display the resulting frame
    cv2.imshow('original',frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    print("No circles were found")
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

#5,7cm de altura
#[166,260]
#69 CM
#2009
# Out:
# Novo frame
# Distância é: 154.28518462733416
# No circles were found
# Novo frame
# Distância é: 154.0388741706648
# No circles were found
# Novo frame
# Distância é: 154.2501988352096
# No circles were found
# Novo frame
# Distância é: 154.60257888303224
# No circles were found
# Novo frame
# Distância é: 154.53412565197982
# No circles were found
# Novo frame
# Distância é: 153.83601904951226
# No circles were found
# Novo frame
# Distância é: 153.84314822761496
# No circles were found
# Novo frame
# Distância é: 153.65337531534826
# No circles were found
# Novo frame
# Distância é: 154.02360834353405
# No circles were found
# Novo frame
# Distância é: 153.97069016152219
# No circles were found
# Novo frame
# Distância é: 154.35330742869064
# No circles were found
# Novo frame
# Distância é: 153.8056123547763
# No circles were found
# Novo frame
# Distância é: 153.98880015532046
# No circles were found
# Novo frame
# Distância é: 153.66568921997646
# No circles were found
# Novo frame
# Distância é: 153.83982115449234
# No circles were found
# Novo frame
# Distância é: 154.11144888804876
# No circles were found
# Novo frame
# Distância é: 153.9897534899136
# No circles were found
# Novo frame
# Distância é: 153.95115759566917
# No circles were found
# Novo frame
# Distância é: 153.7505461461189
# No circles were found
# Novo frame
# Distância é: 153.9897534899136
# No circles were found
# Novo frame
# Distância é: 154.08995226369737
# No circles were found
# Novo frame
# Distância é: 153.9382987452515
# No circles were found
# Novo frame
# Distância é: 153.82413928815777
# No circles were found
# Novo frame
# Distância é: 153.90545187181235
# No circles were found
# Novo frame
# Distância é: 153.84077172478672
# No circles were found
# Novo frame
# Distância é: 153.91973053734742
# No circles were found
# Novo frame
# Distância é: 153.78756690845896
# No circles were found
# Novo frame
# Distância é: 153.9340131777539
# No circles were found
# Novo frame
# Distância é: 154.02933249681365
# No circles were found
# Novo frame
# Distância é: 153.5445733869955
# No circles were found
# Novo frame
# Distância é: 153.75007169452545
# No circles were found
# Novo frame
# Distância é: 153.85027839696585
# No circles were found
# Novo frame
# Distância é: 154.0221774049263
# No circles were found
# Novo frame
# Distância é: 153.8536061486214
# No circles were found
# Novo frame
# Distância é: 153.91830249195513
# No circles were found
# Novo frame
# Distância é: 153.700752697722
# No circles were found
# Novo frame
# Distância é: 153.77379965609927
# No circles were found
# Novo frame
# Distância é: 153.83364287704904
# No circles were found
# Novo frame
# Distância é: 153.7491228045152
# No circles were found
# Novo frame
# Distância é: 153.74580182782694
# No circles were found
# Novo frame
# Distância é: 153.79753860674106
# No circles were found
# Novo frame
# Distância é: 153.73204578800258
# No circles were found
# Novo frame
# Distância é: 153.85693411622213
# No circles were found
# Novo frame
# Distância é: 153.7837686764114
# No circles were found
# Novo frame
# Distância é: 153.6453255165629
# No circles were found
# Novo frame
# Distância é: 153.50772779055
# No circles were found
# Novo frame
# Distância é: 153.72066427107956
# No circles were found
# Novo frame
# Distância é: 153.77949600173062
# No circles were found
# Novo frame
# Distância é: 153.58286421749824
# No circles were found
# Novo frame
# Distância é: 153.12666180106143
# No circles were found
# Novo frame
# Distância é: 153.56962464148384
# No circles were found
# Novo frame
# Distância é: 153.66853131073097
# No circles were found
# Novo frame
# Distância é: 153.70264870468802
# No circles were found
# Novo frame
# Distância é: 153.57718969421126
# No circles were found
# Novo frame
# Distância é: 153.4081885029041
# No circles were found
# Novo frame
# Distância é: 153.72920017176662
# No circles were found
# Novo frame
# Distância é: 153.77000244400244
# No circles were found
# Novo frame
# Distância é: 153.90545187181235
# No circles were found
# Novo frame
# Distância é: 153.89212870190408
# No circles were found
# Novo frame
# Distância é: 153.98880015532046
# No circles were found
# Novo frame
# Distância é: 153.87690645798423
# No circles were found
# Novo frame
# Distância é: 153.8597868317724
# No circles were found
# Novo frame
# Distância é: 153.42751510314952
# No circles were found
# Novo frame
# Distância é: 154.0083470542051
# No circles were found
# Novo frame
# Distância é: 153.94020355681303
# No circles were found
# Novo frame
# Distância é: 154.05748553608194
# No circles were found
# Novo frame
# Distância é: 153.94877608395652
# No circles were found
# Novo frame
# Distância é: 153.95592095068054
# No circles were found
# Novo frame
# Distância é: 153.8845170152755
# No circles were found
# Novo frame
# Distância é: 153.92591919338952
# No circles were found
# Novo frame
# Distância é: 153.81796289981875
# No circles were found
# Novo frame
# Distância é: 153.89165293839847
# No circles were found
# Novo frame
# Distância é: 153.96783127286045
# No circles were found
# Novo frame
# Distância é: 154.09616147561644
# No circles were found
# Novo frame
# Distância é: 154.09425086892503
# No circles were found
# Novo frame
# Distância é: 154.19848265776727
# No circles were found
# Novo frame
# Distância é: 154.34322724403205
# No circles were found
# Novo frame
# Distância é: 154.3777961020168
# No circles were found
# Novo frame
# Distância é: 154.39989392551456
# No circles were found
# Novo frame
# Distância é: 157.3519383450788
# No circles were found
# Novo frame
# Distância é: 162.02070374974028
# No circles were found
# Novo frame
# Distância é: 161.74436371306973
# No circles were found
# Novo frame
# Distância é: 162.73889281900333
# No circles were found
# Novo frame
# Distância é: 162.61301132802527
# No circles were found
# Novo frame
# Distância é: 162.62929202568517
# No circles were found
# Novo frame
# Distância é: 162.59673551893223
# No circles were found
# Novo frame
# Distância é: 162.75127195179013
# No circles were found
# Novo frame
# Distância é: 162.79574758883498
# No circles were found
# Novo frame
# Distância é: 162.6871561246079
# No circles were found
# Novo frame
# Distância é: 162.7585882218665
# No circles were found
# Novo frame
# Distância é: 162.78617380323578
# No circles were found
# Novo frame
# Distância é: 162.6304150126794
# No circles were found
# Novo frame
# Distância é: 162.54849804696113
# No circles were found
# Novo frame
# Distância é: 162.9147159290599
# No circles were found
# Novo frame
# Distância é: 162.98870915404927
# No circles were found
# Novo frame
# Distância é: 163.394349791788
# No circles were found
# Novo frame
# Distância é: 163.28910345642936
# No circles were found
# Novo frame
# Distância é: 163.3306087942573
# No circles were found
# Novo frame
# Distância é: 163.11659893422922
# No circles were found
# Novo frame
# Distância é: 163.25046940150202
# No circles were found
# Novo frame
# Distância é: 163.41143594882837
# No circles were found
# Novo frame
# Distância é: 163.41485382349344
# No circles were found
# Novo frame
# Distância é: 163.7433985790103
# No circles were found
# Novo frame
# Distância é: 163.89203529825812
# No circles were found
# Novo frame
# Distância é: 163.98003041065732
# No circles were found
# Novo frame
# Distância é: 163.97024617607573
# No circles were found
# Novo frame
# Distância é: 163.9829084600574
# No circles were found
# Novo frame
# Distância é: 163.88513971032899
# No circles were found
# Novo frame
# Distância é: 163.90812838895857
# No circles were found
# Novo frame
# Distância é: 163.6403367965757
# No circles were found
# Novo frame
# Distância é: 163.62775369801102
# No circles were found
# Novo frame
# Distância é: 163.91560179271934
# No circles were found
# Novo frame
# Distância é: 163.77722233867712
# No circles were found
# Novo frame
# Distância é: 163.6855454995766
# No circles were found
# Novo frame
# Distância é: 163.5163484301155
# No circles were found
# Novo frame
# Distância é: 163.2334336810457
# No circles were found
# Novo frame
# Distância é: 162.58887998071287
# No circles were found
# Novo frame
# Distância é: 162.55130137577123
# No circles were found
# Novo frame
# Distância é: 162.2109192260755
# No circles were found
# Novo frame
# Distância é: 161.54037275825618
# No circles were found
# Novo frame
# Distância é: 161.40462382911727
# No circles were found
# Novo frame
# Distância é: 162.23934213253972
# No circles were found
# Novo frame
# Distância é: 162.29902309417886
# No circles were found
# Novo frame
# Distância é: 160.24103957318937
# No circles were found
# Novo frame
# Distância é: 158.7292503969881
# No circles were found
# Novo frame
# Distância é: 159.41071706607053
# No circles were found
# Novo frame
# Distância é: 158.56714051469177
# No circles were found
# Novo frame
# Distância é: 159.81573446698746
# No circles were found
# Novo frame
# Distância é: 159.00718899419422
# No circles were found
# Novo frame
# Distância é: 158.0348051375179
# No circles were found
# Novo frame
# Distância é: 158.63015315641584
# No circles were found
# Novo frame
# Distância é: 158.95263783288345
# No circles were found
# Novo frame
# Distância é: 159.25231165596938
# No circles were found
# Novo frame
# Distância é: 159.56058026184635
# No circles were found
# Novo frame
# Distância é: 160.13533311952182
# No circles were found
# Novo frame
# Distância é: 160.18198986530848
# No circles were found
# Novo frame
# Distância é: 160.21902250327634
# No circles were found
# Novo frame
# Distância é: 160.19379458445033
# No circles were found
# Novo frame
# Distância é: 160.48113022330583
# No circles were found
# Novo frame
# Distância é: 160.9999660155945
# No circles were found
# Novo frame
# Distância é: 162.11628398128212
# No circles were found
# Novo frame
# Distância é: 163.04978708274686
# No circles were found
# Novo frame
# Distância é: 162.9491582497623
# No circles were found
# Novo frame
# Distância é: 163.7262080920899
# No circles were found
# Novo frame
# Distância é: 164.58543878504537
# No circles were found
# Novo frame
# Distância é: 165.55836148154657
# No circles were found
# Novo frame
# Distância é: 165.06886905375453
# No circles were found
# Novo frame
# Distância é: 165.34964817927963
# No circles were found
# Novo frame
# Distância é: 167.18133289692057
# No circles were found
# Novo frame
# Distância é: 167.39339470326163
# No circles were found
# Novo frame
# Distância é: 167.5245793281507
# No circles were found
# Novo frame
# Distância é: 168.1820554446428
# No circles were found
# Novo frame
# Distância é: 168.58027639009384
# No circles were found
# Novo frame
# Distância é: 168.47468154675184
# No circles were found
# Novo frame
# Distância é: 168.21000685056964
# No circles were found
# Novo frame
# Distância é: 167.9323546670217
# No circles were found
# Novo frame
# Distância é: 168.1820554446428
# No circles were found
# Novo frame
# Distância é: 168.348104709762
# No circles were found
# Novo frame
# Distância é: 168.1814344605422
# No circles were found
# Novo frame
# Distância é: 168.3144820356995
# No circles were found
# Novo frame
# Distância é: 169.91366794291264
# No circles were found
# Novo frame
# Distância é: 171.4572422925374
# No circles were found
# Novo frame
# Distância é: 170.51041712613838
# No circles were found
# Novo frame
# Distância é: 170.06949118556673
# No circles were found
# Novo frame
# Distância é: 171.02070176145682
# No circles were found
# Novo frame
# Distância é: 170.41601348716316
# No circles were found
# Novo frame
# Distância é: 170.6841150744552
# No circles were found
# Novo frame
# Distância é: 170.09582464231988
# No circles were found
# Novo frame
# Distância é: 170.07462846063768
# No circles were found
# Novo frame
# Distância é: 170.5304819344865
# No circles were found
# Novo frame
# Distância é: 170.28179104500478
# No circles were found
# Novo frame
# Distância é: 170.79001969100588
# No circles were found
# Novo frame
# Distância é: 169.58801941470045
# No circles were found
# Novo frame
# Distância é: 169.63961500692923
# No circles were found
# Novo frame
# Distância é: 170.37080704503964
# No circles were found
# Novo frame
# Distância é: 169.9508214045715
# No circles were found
# Novo frame
# Distância é: 169.0437325123104
# No circles were found
# Novo frame
# Distância é: 169.44558005329236
# No circles were found
# Novo frame
# Distância é: 169.00086928715538
# No circles were found
# Novo frame
# Distância é: 168.70173689816014
# No circles were found
# Novo frame
# Distância é: 167.847721768621
# No circles were found
# Novo frame
# Distância é: 166.50473788891364
# No circles were found
# Novo frame
# Distância é: 166.63505068607725
# No circles were found
# Novo frame
# Distância é: 166.08332325263882
# No circles were found
# Novo frame
# Distância é: 166.92148351328788
# No circles were found
# Novo frame
# Distância é: 166.5403022363308
# No circles were found
# Novo frame
# Distância é: 166.62236795736163
# No circles were found
# Novo frame
# Distância é: 167.676992876314
# No circles were found
# Novo frame
# Distância é: 167.319967956234
# No circles were found
# Novo frame
# Distância é: 167.72871121065057
# No circles were found
# Novo frame
# Distância é: 168.20752171680058
# No circles were found
# Novo frame
# Distância é: 168.27092705623576
# No circles were found
# Novo frame
# Distância é: 168.25600170233932
# No circles were found
# Novo frame
# Distância é: 169.685517311821
# No circles were found
# Novo frame
# Distância é: 168.38486363871937
# No circles were found
# Novo frame
# Distância é: 168.6653964542858
# No circles were found
# Novo frame
# Distância é: 171.10172697927135
# No circles were found
# Novo frame
# Distância é: 170.72697295777397
# No circles were found
# Novo frame
# Distância é: 171.3783394226228
# No circles were found
# Novo frame
# Distância é: 170.30242001001415
# No circles were found
# Novo frame
# Distância é: 170.6633471095333
# No circles were found
# Novo frame
# Distância é: 170.82840188333176
# No circles were found
# Novo frame
# Distância é: 171.25428799362118
# No circles were found
# Novo frame
# Distância é: 170.6257244874305
# No circles were found
# Novo frame
# Distância é: 170.93522745451318
# No circles were found
# Novo frame
# Distância é: 171.03441567797574
# No circles were found
# Novo frame
# Distância é: 171.0128667186892
# No circles were found
# Novo frame
# Distância é: 171.4236952590026
# No circles were found
# Novo frame
# Distância é: 171.05009276586622
# No circles were found
# Novo frame
# Distância é: 170.95935606500842
# No circles were found
# Novo frame
# Distância é: 171.7746087415263
# No circles were found
# Novo frame
# Distância é: 171.28707962398275
# No circles were found
# Novo frame
# Distância é: 170.97631741883797
# No circles were found
# Novo frame
# Distância é: 171.23200043944362
# No circles were found
# Novo frame
# Distância é: 170.85899605272283
# No circles were found
# Novo frame
# Distância é: 170.98936804990947
# No circles were found
# Novo frame
# Distância é: 171.15798956895432
# No circles were found
# Novo frame
# Distância é: 171.09191941834757
# No circles were found
# Novo frame
# Distância é: 170.86876361002982
# No circles were found
# Novo frame
# Distância é: 170.43410614260796
# No circles were found
# Novo frame
# Distância é: 170.98936804990947
# No circles were found
# Novo frame
# Distância é: 171.20906645591666
# No circles were found
# Novo frame
# Distância é: 171.41646220556126
# No circles were found
# Novo frame
# Distância é: 171.58371387849934
# No circles were found
# Novo frame
# Distância é: 171.47830147012667
# No circles were found
# Novo frame
# Distância é: 171.53493648285198
# No circles were found
# Novo frame
# Distância é: 171.87327784004182
# No circles were found
# Novo frame
# Distância é: 171.33695899807697
# No circles were found
# Novo frame
# Distância é: 171.4158047006479
# No circles were found
# Novo frame
# Distância é: 171.5593199800673
# No circles were found
# Novo frame
# Distância é: 171.4315869071048
# No circles were found
# Novo frame
# Distância é: 171.56129747614327
# No circles were found
# Novo frame
# Distância é: 171.72236313910514
# No circles were found
# Novo frame
# Distância é: 171.37374011702946
# No circles were found
# Novo frame
# Distância é: 171.52834813296292
# No circles were found
# Novo frame
# Distância é: 170.46578216058316
# No circles were found
# Novo frame
# Distância é: 170.39663489174754
# No circles were found
# Novo frame
# Distância é: 171.88653496159557
# No circles were found
# Novo frame
# Distância é: 171.41777723808647
# No circles were found
# Novo frame
# Distância é: 171.83948605923138
# No circles were found
# Novo frame
# Distância é: 170.8850465954399
# No circles were found
# Novo frame
# Distância é: 170.78871905306437
# No circles were found
# Novo frame
# Distância é: 171.26346775169375
# No circles were found
# Novo frame
# Distância é: 171.67148605964022
# No circles were found
# Novo frame
# Distância é: 171.3665133849026
# No circles were found
# Novo frame
# Distância é: 171.9170379867929
# No circles were found
# Novo frame
# Distância é: 172.0624819328919
# No circles were found
# Novo frame
# Distância é: 170.8453242861659
# No circles were found
# Novo frame
# Distância é: 171.60416002295406
# No circles were found
# Novo frame
# Distância é: 169.7435860687283
# No circles were found
# Novo frame
# Distância é: 170.75361305693067
# No circles were found
# Novo frame
# Distância é: 170.82189460568918
# No circles were found
# Novo frame
# Distância é: 170.72892181054064
# No circles were found
# Novo frame
# Distância é: 170.89025813400409
# No circles were found
# Novo frame
# Distância é: 169.58165285279387
# No circles were found
# Novo frame
# Distância é: 169.8746190282992
# No circles were found
# Novo frame
# Distância é: 170.75621275872214
# No circles were found
# Novo frame
# Distância é: 170.72047726384824
# No circles were found
# Novo frame
# Distância é: 171.20120549692373
# No circles were found
# Novo frame
# Distância é: 171.31595184582733
# No circles were found
# Novo frame
# Distância é: 170.69580038705837
# No circles were found
# Novo frame
# Distância é: 170.10096430419017
# No circles were found
# Novo frame
# Distância é: 169.73528688196006
# No circles were found
# Novo frame
# Distância é: 171.72566840977976
# No circles were found
# Novo frame
# Distância é: 172.56540122454822
# No circles were found
# Novo frame
# Distância é: 173.17571460559807
# No circles were found
# Novo frame
# Distância é: 174.48394094643686
# No circles were found
# Novo frame
# Distância é: 172.04187154697755
# No circles were found
# Novo frame
# Distância é: 171.41185983004743
# No circles were found
# Novo frame
# Distância é: 171.63253290860825
# No circles were found
# Novo frame
# Distância é: 171.93362253048696
# No circles were found
# Novo frame
# Distância é: 172.3431196700348
# No circles were found
# Novo frame
# Distância é: 172.59224022857924
# No circles were found
# Novo frame
# Distância é: 171.7382301791839
# No circles were found
# Novo frame
# Distância é: 168.70925854382378
# No circles were found
# Novo frame
# Distância é: 165.99667694977109
# No circles were found
# Novo frame
# Distância é: 165.94714039976844
# No circles were found
# Novo frame
# Distância é: 167.2716813927755
# No circles were found
# Novo frame
# Distância é: 172.08775638484775
# No circles were found
# Novo frame
# Distância é: 175.803826060666
# No circles were found
# Novo frame
# Distância é: 178.31579366006272
# No circles were found
# Novo frame
# Distância é: 176.270266194785
# No circles were found
# Novo frame
# Distância é: 172.60432186663462
# No circles were found
# Novo frame
# Distância é: 170.13759788573748
# No circles were found
# Novo frame
# Distância é: 167.748426025001
# No circles were found
# Novo frame
# Distância é: 166.9269479381786
# No circles were found
# Novo frame
# Distância é: 165.29479263459044
# No circles were found
# Novo frame
# Distância é: 165.12056138083472
# No circles were found
# Novo frame
# Distância é: 165.11527243607964
# No circles were found
# Novo frame
# Distância é: 164.76440226868186
# No circles were found
# Novo frame
# Distância é: 164.57438202249315
# No circles were found
# Novo frame
# Distância é: 164.53075865599624
# No circles were found
# Novo frame
# Distância é: 164.4349092272348
# No circles were found
# Novo frame
# Distância é: 164.61105247779244
# No circles were found
# Novo frame
# Distância é: 164.30621209509184
# No circles were found
# Novo frame
# Distância é: 164.0422300128055
# No circles were found
# Novo frame
# Distância é: 164.8561502178881
# No circles were found
# Novo frame
# Distância é: 168.06543120733167
# No circles were found
# Novo frame
# Distância é: 169.41446925799863
# No circles were found
# Novo frame
# Distância é: 170.82124391882408
# No circles were found
# Novo frame
# Distância é: 172.1862999942802
# No circles were found
# Novo frame
# Distância é: 176.42131646695816
# No circles were found
# Novo frame
# Distância é: 179.1543281285415
# No circles were found
# Novo frame
# Distância é: 175.5490336701272
# No circles were found
# Novo frame
# Distância é: 171.33170648553747
# No circles were found
# Novo frame
# Distância é: 171.12919712517728
# No circles were found
# Novo frame
# Distância é: 173.81653770228598
# No circles were found
# Novo frame
# Distância é: 174.35371972760007
# No circles were found
# Novo frame
# Distância é: 172.90651502553249
# No circles were found
# Novo frame
# Distância é: 172.5050592156779
# No circles were found
# Novo frame
# Distância é: 175.0336538296694
# No circles were found
# Novo frame
# Distância é: 178.75408641062577
# No circles were found
# Novo frame
# Distância é: 181.5416775557014
# No circles were found
# Novo frame
# Distância é: 181.88867033324232
# No circles were found
# Novo frame
# Distância é: 180.3223733135072
# No circles were found
# Novo frame
# Distância é: 176.0818196624853
# No circles were found
# Novo frame
# Distância é: 172.99565811394888
# No circles were found
# Novo frame
# Distância é: 169.25410817948975
# No circles were found
# Novo frame
# Distância é: 167.0460842334797
# No circles were found
# Novo frame
# Distância é: 165.6194099347499
# No circles were found
# Novo frame
# Distância é: 165.67043419649124
# No circles were found
# Novo frame
# Distância é: 165.71853508257792
# No circles were found
# Novo frame
# Distância é: 165.8535598893525
# No circles were found
# Novo frame
# Distância é: 165.77084034942777
# No circles were found
# Novo frame
# Distância é: 165.80415131731687
# No circles were found
# Novo frame
# Distância é: 165.51987048473978
# No circles were found
# Novo frame
# Distância é: 165.68230706421875
# No circles were found
# Novo frame
# Distância é: 166.09468696334986
# No circles were found
# Novo frame
# Distância é: 166.2540242309312
# No circles were found
# Novo frame
# Distância é: 165.75775938969204
# No circles were found
# Novo frame
# Distância é: 165.40692133015628
# No circles were found
# Novo frame
# Distância é: 165.8529643424472
# No circles were found
# Novo frame
# Distância é: 165.67043419649124
# No circles were found
# Novo frame
# Distância é: 165.20054513100308
# No circles were found
# Novo frame
# Distância é: 165.93938567930812
# No circles were found
# Novo frame
# Distância é: 165.8613025829776
# No circles were found
# Novo frame
# Distância é: 165.61881690663293
# No circles were found
# Novo frame
# Distância é: 165.67399578879957
# No circles were found
# Novo frame
# Distância é: 166.17250129742112
# No circles were found
# Novo frame
# Distância é: 165.6010290247846
# No circles were found
# Novo frame
# Distância é: 165.6924010090425
# No circles were found
# Novo frame
# Distância é: 165.71794098902464
# No circles were found
# Novo frame
# Distância é: 166.02355266781754
# No circles were found
# Novo frame
# Distância é: 165.78511401991807
# No circles were found
# Novo frame
# Distância é: 166.1012670199915
# No circles were found
# Novo frame
# Distância é: 165.74527590731182
# No circles were found
# Novo frame
# Distância é: 165.6585638808429
# No circles were found
# Novo frame
# Distância é: 165.65381646896094
# No circles were found
# Novo frame
# Distância é: 166.97250569203894
# No circles were found
# Novo frame
# Distância é: 168.4784270793733
# No circles were found
# Novo frame
# Distância é: 169.57083134293595
# No circles were found
# Novo frame
# Distância é: 170.4192438959023
# No circles were found
# Novo frame
# Distância é: 171.19465552483135
# No circles were found
# Novo frame
# Distância é: 169.62623385013404
# No circles were found
# Novo frame
# Distância é: 168.0270231893481
# No circles were found
# Novo frame
# Distância é: 166.99195502299506
# No circles were found
# Novo frame
# Distância é: 167.6474610136592
# No circles were found
# Novo frame
# Distância é: 167.76876421014944
# No circles were found
# Novo frame
# Distância é: 168.05489735586778
# No circles were found
# Novo frame
# Distância é: 168.44410237785016
# No circles were found
# Novo frame
# Distância é: 169.29969817137135
# No circles were found
# Novo frame
# Distância é: 168.79582984303678
# No circles were found
# Novo frame
# Distância é: 169.10745724666728
# No circles were found
# Novo frame
# Distância é: 169.32187328401128
# No circles were found
# Novo frame
# Distância é: 169.25600702721187
# No circles were found
# Novo frame
# Distância é: 169.4919605928778
# No circles were found
# Novo frame
# Distância é: 169.41002625739355
# No circles were found
# Novo frame
# Distância é: 169.67085002541052
# No circles were found
# Novo frame
# Distância é: 169.3434231678383
# No circles were found
# Novo frame
# Distância é: 169.05256134317267
# No circles were found
# Novo frame
# Distância é: 169.36498128183175
# No circles were found
# Novo frame
# Distância é: 169.19780475202924
# No circles were found
# Novo frame
# Distância é: 169.26550222455126
# No circles were found
# Novo frame
# Distância é: 169.4030451055019
# No circles were found
# Novo frame
# Distância é: 169.21804221099399
# No circles were found
# Novo frame
# Distância é: 169.35420119573683
# No circles were found
# Novo frame
# Distância é: 169.40875689285303
# No circles were found
# Novo frame
# Distância é: 169.3675180718636
# No circles were found
# Novo frame
# Distância é: 169.80171448228938
# No circles were found
# Novo frame
# Distância é: 170.02712642154472
# No circles were found
# Novo frame
# Distância é: 169.56701248110377
# No circles were found
# Novo frame
# Distância é: 169.49704570765476
# No circles were found
# Novo frame
# Distância é: 169.4093915715566
# No circles were found
# Novo frame
# Distância é: 168.8743610129451
# No circles were found
# Novo frame
# Distância é: 168.45970191394466
# No circles were found
# Novo frame
# Distância é: 168.56714433338576
# No circles were found
# Novo frame
# Distância é: 168.72054289893552
# No circles were found
# Novo frame
# Distância é: 168.8819057728565
# No circles were found
# Novo frame
# Distância é: 168.86241721081677
# No circles were found
# Novo frame
# Distância é: 168.68419030318856
# No circles were found
# Novo frame
# Distância é: 168.40730464772972
# No circles were found
# Novo frame
# Distância é: 168.39421296885155
# No circles were found
# Novo frame
# Distância é: 168.91209492792936
# No circles were found
# Novo frame
# Distância é: 168.6641437543645
# No circles were found
# Novo frame
# Distância é: 168.7475091376885
# No circles were found
# Novo frame
# Distância é: 168.74249118402759
# No circles were found
# Novo frame
# Distância é: 168.45658166000584
# No circles were found
# Novo frame
# Distância é: 168.44909375789624
# No circles were found
# Novo frame
# Distância é: 168.47967564576203
# No circles were found
# Novo frame
# Distância é: 168.60905257549487
# No circles were found
# Novo frame
# Distância é: 168.89951414593875
# No circles were found
# Novo frame
# Distância é: 168.7995968363201
# No circles were found
# Novo frame
# Distância é: 168.44285460216594
# No circles were found
# Novo frame
# Distância é: 168.7995968363201
# No circles were found
# Novo frame
# Distância é: 168.6491135321079
# No circles were found
# Novo frame
# Distância é: 168.5258921255324
# No circles were found
# Novo frame
# Distância é: 168.5965393799917
# No circles were found
# Novo frame
# Distância é: 168.99582869811562
# No circles were found
# Novo frame
# Distância é: 168.5708960364335
# No circles were found
# Novo frame
# Distância é: 168.49153841108972
# No circles were found
# Novo frame
# Distância é: 168.57652406071955
# No circles were found
# Novo frame
# Distância é: 168.81780752654194
# No circles were found
# Novo frame
# Distância é: 168.45158961431915
# No circles were found
# Novo frame
# Distância é: 168.56839487323566
# No circles were found
# Novo frame
# Distância é: 168.44285460216594
# No circles were found
# Novo frame
# Distância é: 168.41291630204165
# No circles were found
# Novo frame
# Distância é: 168.56401810552077
# No circles were found
# Novo frame
# Distância é: 168.74625460730508
# No circles were found
# Novo frame
# Distância é: 168.63659141586547
# No circles were found
# Novo frame
# Distância é: 168.54401436515036
# No circles were found
# Novo frame
# Distância é: 168.7882966129986
# No circles were found
# Novo frame
# Distância é: 168.6892030573516
# No circles were found
# Novo frame
# Distância é: 168.48529453804613
# No circles were found
# Novo frame
# Distância é: 168.51402210314404
# No circles were found
# Novo frame
# Distância é: 168.47156046038458
# No circles were found
# Novo frame
# Distância é: 168.47343309138955
# No circles were found
# Novo frame
# Distância é: 168.64159992764013
# No circles were found
# Novo frame
# Distância é: 168.58527988572126
# No circles were found
# Novo frame
# Distância é: 168.5696454409179
# No circles were found
# Novo frame
# Distância é: 168.52401774471008
# No circles were found
# Novo frame
# Distância é: 168.80085255679396
# No circles were found
# Novo frame
# Distância é: 169.10556339414921
# No circles were found
# Novo frame
# Distância é: 168.70863170159194
# No circles were found
# Novo frame
# Distância é: 168.5940370751912
# No circles were found
# Novo frame
# Distância é: 169.05193066652026
# No circles were found
# Novo frame
# Distância é: 168.64660888570015
# No circles were found
# Novo frame
# Distância é: 168.57714943154843
# No circles were found
# Novo frame
# Distância é: 168.60467264014676
# No circles were found
# Novo frame
# Distância é: 168.753154870688
# No circles were found
# Novo frame
# Distância é: 168.51777026029683
# No circles were found
# Novo frame
# Distância é: 168.92908344390918
# No circles were found
# Novo frame
# Distância é: 168.65287071096495
# No circles were found
# Novo frame
# Distância é: 168.6641437543645
# No circles were found
# Novo frame
# Distância é: 168.9655946323593
# No circles were found
# Novo frame
# Distância é: 168.60905257549487
# No circles were found
# Novo frame
# Distância é: 168.7368465212038
# No circles were found
# Novo frame
# Distância é: 168.86116011590164
# No circles were found
# Novo frame
# Distância é: 168.97630067473983
# No circles were found
# Novo frame
# Distância é: 167.63331585808865
# No circles were found
# Novo frame
# Distância é: 166.7015313757145
# No circles were found
# Novo frame
# Distância é: 166.19167237474403
# No circles were found
# Novo frame
# Distância é: 166.29663169556807
# No circles were found
# Novo frame
# Distância é: 165.8172432642077
# No circles were found
# Novo frame
# Distância é: 164.76089901587181
# No circles were found
# Novo frame
# Distância é: 163.92537624795645
# No circles were found
# Novo frame
# Distância é: 162.672543825472
# No circles were found
# Novo frame
# Distância é: 161.84166886216502
# No circles were found
# Novo frame
# Distância é: 160.58211763376144
# No circles were found
# Novo frame
# Distância é: 159.2285915497728
# No circles were found
# Novo frame
# Distância é: 158.36869969407329
# No circles were found
# Novo frame
# Distância é: 158.59108688553513
# No circles were found
# Novo frame
# Distância é: 158.4138288103561
# No circles were found
# Novo frame
# Distância é: 158.33086247861078
# No circles were found
# Novo frame
# Distância é: 158.24699173794923
# No circles were found
# Novo frame
# Distância é: 158.25785635255306
# No circles were found
# Novo frame
# Distância é: 158.30133719937663
# No circles were found
# Novo frame
# Distância é: 158.46159354899098
# No circles were found
# Novo frame
# Distância é: 158.10492321894836
# No circles were found
# Novo frame
# Distância é: 158.64839396547842
# No circles were found
# Novo frame
# Distância é: 158.8363796735768
# No circles were found
# Novo frame
# Distância é: 158.18391773036657
# No circles were found
# Novo frame
# Distância é: 158.16996891848427
# No circles were found
# Novo frame
# Distância é: 158.30703377406647
# No circles were found
# Novo frame
# Distância é: 158.45639963656512
# No circles were found
# Novo frame
# Distância é: 157.92671757604782
# No circles were found
# Novo frame
# Distância é: 158.45847714024788
# No circles were found
# Novo frame
# Distância é: 158.8363796735768
# No circles were found
# Novo frame
# Distância é: 157.8989594596877
# No circles were found
# Novo frame
# Distância é: 158.0734616564337
# No circles were found
# Novo frame
# Distância é: 158.35211017847462
# No circles were found
# Novo frame
# Distância é: 158.34278086668118
# No circles were found
# Novo frame
# Distância é: 157.96478026359264
# No circles were found
# Novo frame
# Distância é: 158.22320087515715
# No circles were found
# Novo frame
# Distância é: 158.1679027416512
# No circles were found
# Novo frame
# Distância é: 158.45276420173303
# No circles were found
# Novo frame
# Distância é: 158.48705110469623
# No circles were found
# Novo frame
# Distância é: 158.1958029628471
# No circles were found
# Novo frame
# Distância é: 158.22164966984005
# No circles were found
# Novo frame
# Distância é: 158.2516477273505
# No circles were found
# Novo frame
# Distância é: 158.5499682771017
# No circles were found
# Novo frame
# Distância é: 158.14879444371104
# No circles were found
# Novo frame
# Distância é: 157.88816858881182
# No circles were found
# Novo frame
# Distância é: 158.19528615790054
# No circles were found
# Novo frame
# Distância é: 158.21699632761607
# No circles were found
# Novo frame
# Distância é: 158.33241689834486
# No circles were found
# Novo frame
# Distância é: 158.25785635255306
# No circles were found
# Novo frame
# Distância é: 158.31273096378524
# No circles were found
# Novo frame
# Distância é: 158.4636712569735
# No circles were found
# Novo frame
# Distância é: 157.97918954002503
# No circles were found
# Novo frame
# Distância é: 157.9755868512477
# No circles were found
# Novo frame
# Distância é: 158.22785476486712
# No circles were found
# Novo frame
# Distância é: 158.36351491037007
# No circles were found
# Novo frame
# Distância é: 157.32041579235351
# No circles were found
# Novo frame
# Distância é: 156.486907584475
# No circles were found
# Novo frame
# Distância é: 157.01077602218544
# No circles were found
# Novo frame
# Distância é: 157.09573200213273
# No circles were found
# Novo frame
# Distância é: 157.04009048265627
# No circles were found
# Novo frame
# Distância é: 157.13978129719916
# No circles were found
# Novo frame
# Distância é: 156.95118689634833
# No circles were found
# Novo frame
# Distância é: 156.42391546863783
# No circles were found
# Novo frame
# Distância é: 156.9330206656079
# No circles were found
# Novo frame
# Distância é: 156.94311223721004
# No circles were found
# Novo frame
# Distância é: 157.17981219874216
# No circles were found
# Novo frame
# Distância é: 156.84480237298143
# No circles were found
# Novo frame
# Distância é: 157.09421372155725
# No circles were found
# Novo frame
# Distância é: 156.9683496859935
# No circles were found
# Novo frame
# Distância é: 156.51843219369107
# No circles were found
# Novo frame
# Distância é: 156.9466447472328
# No circles were found
# Novo frame
# Distância é: 156.87251208932327
# No circles were found
# Novo frame
# Distância é: 157.0754918799087
# No circles were found
# Novo frame
# Distância é: 157.04666321800673
# No circles were found
# Novo frame
# Distância é: 157.01835577434522
# No circles were found
# Novo frame
# Distância é: 157.09421372155725
# No circles were found
# Novo frame
# Distância é: 157.01987185651092
# No circles were found
# Novo frame
# Distância é: 156.9072959666282
# No circles were found
# Novo frame
# Distância é: 157.07448007914485
# No circles were found
# Novo frame
# Distância é: 156.96532054928434
# No circles were found
# Novo frame
# Distância é: 156.7934522881773
# No circles were found
# Novo frame
# Distância é: 157.0906712380673
# No circles were found
# Novo frame
# Distância é: 157.31330041812856
# No circles were found
# Novo frame
# Distância é: 157.08409297591334
# No circles were found
# Novo frame
# Distância é: 157.25691981706387
# No circles were found
# Novo frame
# Distância é: 156.85689207969753
# No circles were found
# Novo frame
# Distância é: 156.87503188275878
# No circles were found
# Novo frame
# Distância é: 157.48943525098667
# No circles were found
# Novo frame
# Distância é: 156.9138520414857
# No circles were found
# Novo frame
# Distância é: 157.11192973453498
# No circles were found
# Novo frame
# Distância é: 156.41941894211902
# No circles were found
# Novo frame
# Distância é: 156.9199045323576
# No circles were found
# Novo frame
# Distância é: 157.06183421911615
# No circles were found
# Novo frame
# Distância é: 156.49841436101102
# No circles were found
# Novo frame
# Distância é: 157.14180744322658
# No circles were found
# Novo frame
# Distância é: 157.0532367787095
# No circles were found
# Novo frame
# Distância é: 156.96986432011332
# No circles were found
# Novo frame
# Distância é: 157.02290415259301
# No circles were found
# Novo frame
# Distância é: 157.0734682979333
# No circles were found
# Novo frame
# Distância é: 157.3097430930423
# No circles were found
# Novo frame
# Distância é: 156.95724370866208
# No circles were found
# Novo frame
# Distância é: 157.06992721765783
# No circles were found
# Novo frame
# Distância é: 157.0320020949976
# No circles were found
# Novo frame
# Distância é: 157.26859730484216
# No circles were found
# Novo frame
# Distância é: 156.84228403591956
# No circles were found
# Novo frame
# Distância é: 157.1615664752033
# No circles were found
# Novo frame
# Distância é: 157.1088922780634
# No circles were found
# Novo frame
# Distância é: 157.24575247983663
# No circles were found
# Novo frame
# Distância é: 157.06537475204698
# No circles were found
# Novo frame
# Distância é: 157.04160719449007
# No circles were found
# Novo frame
# Distância é: 157.24422984544674
# No circles were found
# Novo frame
# Distância é: 157.1377552295435
# No circles were found
# Novo frame
# Distância é: 157.39416756948592
# No circles were found
# Novo frame
# Distância é: 157.11496736718686
# No circles were found
# Novo frame
# Distância é: 157.25184345974736
# No circles were found
# Novo frame
# Distância é: 156.68286868728188
# No circles were found
# Novo frame
# Distância é: 157.34380167877237
# No circles were found
# Novo frame
# Distância é: 156.90931313290454
# No circles were found
# Novo frame
# Distância é: 157.18893744385807
# No circles were found
# Novo frame
# Distância é: 157.04009048265627
# No circles were found
# Novo frame
# Distância é: 157.03301307510785
# No circles were found
# Novo frame
# Distância é: 157.22799116366664
# No circles were found
# Novo frame
# Distância é: 157.14889957157345
# No circles were found
# Novo frame
# Distância é: 157.15497930306643
# No circles were found
# Novo frame
# Distância é: 157.11699255350783
# No circles were found
# Novo frame
# Distância é: 157.23813975017424
# No circles were found
# Novo frame
# Distância é: 157.23052812606875
# No circles were found
# Novo frame
# Distância é: 157.088647069382
# No circles were found
# Novo frame
# Distância é: 157.0613284482425
# No circles were found
# Novo frame
# Distância é: 157.34888694728963
# No circles were found
# Novo frame
# Distância é: 157.42420661648944
# No circles were found
# Novo frame
# Distância é: 157.06689219660123
# No circles were found
# Novo frame
# Distância é: 157.22342494079228
# No circles were found
# Novo frame
# Distância é: 157.0446407499996
# No circles were found
# Novo frame
# Distância é: 157.12306858238082
# No circles were found
# Novo frame
# Distância é: 157.32753213216367
# No circles were found
# Novo frame
# Distância é: 157.0911772924649
# No circles were found
# Novo frame
# Distância é: 157.3270237901506
# No circles were found
# Novo frame
# Distância é: 156.73059198555734
# No circles were found
# Novo frame
# Distância é: 157.27824588755897
# No circles were found
# Novo frame
# Distância é: 157.48892533798445
# No circles were found
# Novo frame
# Distância é: 157.13623573023023
# No circles were found
# Novo frame
# Distância é: 157.08965914394378
# No circles were found
# Novo frame
# Distância é: 157.16916808779226
# No circles were found
# Novo frame
# Distância é: 157.21023586469778
# No circles were found
# Novo frame
# Distância é: 157.1337033293274
# No circles were found
# Novo frame
# Distância é: 157.0127971820975
# No circles were found
# Novo frame
# Distância é: 157.0213879825928
# No circles were found
# Novo frame
# Distância é: 156.97390355879827
# No circles were found
# Novo frame
# Distância é: 157.18893744385807
# No circles were found
# Novo frame
# Distância é: 157.13927477293808
# No circles were found
# Novo frame
# Distância é: 157.1615664752033
# No circles were found
# Novo frame
# Distância é: 157.21987370914724
# No circles were found
# Novo frame
# Distância é: 157.1610597402467
# No circles were found
# Novo frame
# Distância é: 157.13927477293808
# No circles were found
# Novo frame
# Distância é: 157.1245876997455
# No circles were found
# Novo frame
# Distância é: 157.10332406538845
# No circles were found
# Novo frame
# Distância é: 157.2498130544656
# No circles were found
# Novo frame
# Distância é: 157.17879838071622
# No circles were found
# Novo frame
# Distância é: 157.2675817678509
# No circles were found
# Novo frame
# Distância é: 157.0613284482425
# No circles were found
# Novo frame
# Distância é: 157.0679038507384
# No circles were found
# Novo frame
# Distância é: 157.33414102677114
# No circles were found
# Novo frame
# Distância é: 157.1271196599384
# No circles were found
# Novo frame
# Distância é: 157.15497930306643
# No circles were found
# Novo frame
# Distância é: 157.1661273103955
# No circles were found
# Novo frame
# Distância é: 156.84631343344714
# No circles were found
# Novo frame
# Distância é: 157.07599778762292
# No circles were found
# Novo frame
# Distância é: 157.23610987565826
# No circles were found
# Novo frame
# Distância é: 157.03604613260003
# No circles were found
# Novo frame
# Distância é: 156.72255132364867
# No circles were found
# Novo frame
# Distância é: 157.1610597402467
# No circles were found
# Novo frame
# Distância é: 157.27672230906742
# No circles were found
# Novo frame
# Distância é: 157.26301209483148
# No circles were found
# Novo frame
# Distância é: 157.14028782635847
# No circles were found
# Novo frame
# Distância é: 156.69542322326924
# No circles were found
# Novo frame
# Distância é: 157.2350949678802
# No circles were found
# Novo frame
# Distância é: 156.99511467888775
# No circles were found
# Novo frame
# Distância é: 157.3021210661261
# No circles were found
# Novo frame
# Distância é: 157.12357494993998
# No circles were found
# Novo frame
# Distância é: 157.03250758261197
# No circles were found
# Novo frame
# Distância é: 156.66881118887736
# No circles were found
# Novo frame
# Distância é: 157.25844282012739
# No circles were found
# Novo frame
# Distância é: 157.42064176250383
# No circles were found
# Novo frame
# Distância é: 157.18741645930172
# No circles were found
# Novo frame
# Distância é: 157.10383024207636
# No circles were found
# Novo frame
# Distância é: 157.05070838844568
# No circles were found
# Novo frame
# Distância é: 157.1053488014962
# No circles were found
# Novo frame
# Distância é: 157.10332406538845
# No circles were found
# Novo frame
# Distância é: 156.97794310931934
# No circles were found
# Novo frame
# Distância é: 157.2650430114397
# No circles were found
# Novo frame
# Distância é: 157.14991281115533
# No circles were found
# Novo frame
# Distância é: 156.98905348148458
# No circles were found
# Novo frame
# Distância é: 156.85386939092808
# No circles were found
# Novo frame
# Distância é: 157.19958557215978
# No circles were found
# Novo frame
# Distância é: 157.00824968205347
# No circles were found
# Novo frame
# Distância é: 156.97188390047882
# No circles were found
# Novo frame
# Distância é: 157.12914531622496
# No circles were found
# Novo frame
# Distância é: 157.00875494032402
# No circles were found
# Novo frame
# Distância é: 157.1813329625649
# No circles were found
# Novo frame
# Distância é: 157.24727515845947
# No circles were found
# Novo frame
# Distância é: 157.28637238738418
# No circles were found
# Novo frame
# Distância é: 157.17068854267762
# No circles were found
# Novo frame
# Distância é: 157.21682998782825
# No circles were found
# Novo frame
# Distância é: 157.0138077913241
# No circles were found
# Novo frame
# Distância é: 156.99511467888775
# No circles were found
# Novo frame
# Distância é: 157.2675817678509
# No circles were found
# Novo frame
# Distância é: 157.2995806366802
# No circles were found
# Novo frame
# Distância é: 157.1073736158899
# No circles were found
# Novo frame
# Distância é: 157.156499346198
# No circles were found
# Novo frame
# Distância é: 157.16714088325085
# No circles were found
# Novo frame
# Distância é: 157.34939550126006
# No circles were found
# Novo frame
# Distância é: 157.03250758261197
# No circles were found
# Novo frame
# Distância é: 156.2637786834288
# No circles were found
# Novo frame
# Distância é: 157.2609812569028
# No circles were found
# Novo frame
# Distância é: 157.0047130107329
# No circles were found
# Novo frame
# Distância é: 157.26351981660713
# No circles were found
# Novo frame
# Distância é: 157.30516974394058
# No circles were found
# Novo frame
# Distância é: 157.09927482801072
# No circles were found
# Novo frame
# Distância é: 156.87452791435774
# No circles were found
# Novo frame
# Distância é: 157.00218696325072
# No circles were found
# Novo frame
# Distância é: 157.20719270308945
# No circles were found
# Novo frame
# Distância é: 157.14535338737193
# No circles were found
# Novo frame
# Distância é: 157.1190178181438
# No circles were found
# Novo frame
# Distância é: 157.30110487957754
# No circles were found
# Novo frame
# Distância é: 157.1544726318239
# No circles were found
# Novo frame
# Distância é: 156.7733287629565
# No circles were found
# Novo frame
# Distância é: 157.26148895900903
# No circles were found
# Novo frame
# Distância é: 156.78037111539646
# No circles were found
# Novo frame
# Distância é: 157.30262916678575
# No circles were found
# Novo frame
# Distância é: 157.08156309512472
# No circles were found
# Novo frame
# Distância é: 157.0623399948759
# No circles were found
# Novo frame
# Distância é: 157.02391495699325
# No circles were found
# Novo frame
# Distância é: 157.24422984544674
# No circles were found
# Novo frame
# Distância é: 157.18893744385807
# No circles were found
# Novo frame
# Distância é: 156.70295739359585
# No circles were found
# Novo frame
# Distância é: 156.7939554755993
# No circles were found
# Novo frame
# Distância é: 157.00117657839624
# No circles were found
# Novo frame
# Distância é: 156.988548413389
# No circles were found
# Novo frame
# Distância é: 156.25481360663517
# No circles were found
# Novo frame
# Distância é: 156.86696897114308
# No circles were found
# Novo frame
# Distância é: 156.94109376714448
# No circles were found
# Novo frame
# Distância é: 156.88208795040532
# No circles were found
# Novo frame
# Distância é: 156.74567156289345
# No circles were found
# Novo frame
# Distância é: 157.16866127930288
# No circles were found
# Novo frame
# Distância é: 157.17474330477887
# No circles were found
# Novo frame
# Distância é: 157.17119537077875
# No circles were found
# Novo frame
# Distância é: 156.73411016432456
# No circles were found
# Novo frame
# Distância é: 157.04261836012722
# No circles were found
# Novo frame
# Distância é: 156.60108702417457
# No circles were found
# Novo frame
# Distância é: 157.00420779148234
# No circles were found
# Novo frame
# Distância é: 156.89922807941036
# No circles were found
# Novo frame
# Distância é: 156.82768007271213
# No circles were found
# Novo frame
# Distância é: 156.6326807027381
# No circles were found
# Novo frame
# Distância é: 157.0178504233821
# No circles were found
# Novo frame
# Distância é: 156.9269666569773
# No circles were found
# Novo frame
# Distância é: 157.1190178181438
# No circles were found
# Novo frame
# Distância é: 156.6015883618245
# No circles were found
# Novo frame
# Distância é: 157.05728245714343
# No circles were found
# Novo frame
# Distância é: 156.54797252302097
# No circles were found
# Novo frame
# Distância é: 156.74416340929105
# No circles were found
# Novo frame
# Distância é: 157.26859730484216
# No circles were found
# Novo frame
# Distância é: 157.11800517603612
# No circles were found
# Novo frame
# Distância é: 156.83271546126807
# No circles were found
# Novo frame
# Distância é: 156.84681712997426
# No circles were found
# Novo frame
# Distância é: 156.923939915389
# No circles were found
# Novo frame
# Distância é: 157.0320020949976
# No circles were found
# Novo frame
# Distância é: 157.21987370914724
# No circles were found
# Novo frame
# Distância é: 157.11142347955544
# No circles were found
# Novo frame
# Distância é: 156.92595772365473
# No circles were found
# Novo frame
# Distância é: 156.92848009345005
# No circles were found
# Novo frame
# Distância é: 156.99814554087035
# No circles were found
# Novo frame
# Distância é: 156.90880883404202
# No circles were found
# Novo frame
# Distância é: 156.78691129251226
# No circles were found
# Novo frame
# Distância é: 157.1661273103955
# No circles were found
# Novo frame
# Distância é: 157.40383928365958
# No circles were found
# Novo frame
# Distância é: 157.07397418609509
# No circles were found
# Novo frame
# Distância é: 156.83070124764325
# No circles were found
# Novo frame
# Distância é: 157.00370257710892
# No circles were found
# Novo frame
# Distância é: 156.91133037697966
# No circles were found
# Novo frame
# Distância é: 157.09218941593218
# No circles were found
# Novo frame
# Distância é: 157.1068674049519
# No circles were found
# Novo frame
# Distância é: 157.28992812718926
# No circles were found
# Novo frame
# Distância é: 157.06588056201164
# No circles were found
# Novo frame
# Distância é: 156.83976582015885
# No circles were found
# Novo frame
# Distância é: 156.98450804410732
# No circles were found
# Novo frame
# Distância é: 157.08611696855593
# No circles were found
# Novo frame
# Distância é: 157.04666321800673
# No circles were found
# Novo frame
# Distância é: 157.07599778762292
# No circles were found
# Novo frame
# Distância é: 156.9759232950768
# No circles were found
# Novo frame
# Distância é: 156.8171073352575
# No circles were found
# Novo frame
# Distância é: 156.92091334892953
# No circles were found
# Novo frame
# Distância é: 156.97794310931934
# No circles were found
# Novo frame
# Distância é: 157.09218941593218
# No circles were found
# Novo frame
# Distância é: 157.17829147905977
# ...
# Distância é: 213.7000104142915
# No circles were found
# Novo frame
# Distância é: 214.09219469060454
# No circles were found
# Novo frame
# Distância é: 215.18941550018525
# No circles were found
# Novo frame
# Distância é: 216.11764603235514
# No circles were found
# Novo frame
# Distância é: 218.46663064659523
# No circles were found
# Novo frame
# Distância é: 218.87748654646188
# No circles were found
# Novo frame
# Distância é: 218.7721632696957
# No circles were found
# Novo frame
# Distância é: 219.1490178831996
# No circles were found
# Novo frame
# Distância é: 219.82258517324553
# No circles were found
# Novo frame
# Distância é: 220.9699296702364
# No circles were found
# Novo frame
# Distância é: 222.3331516340848
# No circles were found
# Novo frame
# Distância é: 222.62784696159108
# No circles were found
# Novo frame
# Distância é: 223.2396478445924
# No circles were found
# Novo frame
# Distância é: 224.45934167913677
# No circles were found
# Novo frame
# Distância é: 225.75780379076426
# No circles were found
# Novo frame
# Distância é: 229.0612429024168
# No circles were found
# Novo frame
# Distância é: 231.1381522820144
# No circles were found
# Novo frame
# Distância é: 233.71462820690954
# No circles were found
# Novo frame
# Distância é: 235.042381475828
# No circles were found
# Novo frame
# Distância é: 236.55701640659728
# No circles were found
# Novo frame
# Distância é: 237.85500464519157
# No circles were found
# Novo frame
# Distância é: 237.90420560411138
# No circles were found
# Novo frame
# Distância é: 238.50409256712058
# No circles were found
# Novo frame
# Distância é: 238.6547747029126
# No circles were found
# Novo frame
# Distância é: 239.03362451127174
# No circles were found
# Novo frame
# Distância é: 240.08348275039816
# No circles were found
# Novo frame
# Distância é: 242.04932200087185
# No circles were found
# Novo frame
# Distância é: 245.30534764499902
# No circles were found
# Novo frame
# Distância é: 248.62616135475594
# No circles were found
# Novo frame
# Distância é: 253.00232269674825
# No circles were found
# Novo frame
# Distância é: 257.2305353367631
# No circles were found
# Novo frame
# Distância é: 263.3333498374222
# No circles were found
# Novo frame
# Distância é: 270.5412710319122
# No circles were found
# Novo frame
# Distância é: 279.6570812320076
# No circles were found
# Novo frame
# Distância é: 289.0366035585282
# No circles were found
# Novo frame
# Distância é: 302.32200344525216
# No circles were found
# Novo frame
# Distância é: 307.5627898485761
# No circles were found
# Novo frame
# Distância é: 307.2594060950796
# No circles were found
# Novo frame
# Distância é: 315.23516053796084
# No circles were found
# Novo frame
# Distância é: 320.59923385878295
# No circles were found
# Novo frame
# Distância é: 325.34845931809014
# No circles were found
# Novo frame
# Distância é: 325.5644642942667
# No circles were found
# Novo frame
# Distância é: 322.78509884595775
# No circles were found
# Novo frame
# Distância é: 323.0576360535904
# No circles were found
# Novo frame
# Distância é: 323.8084716842961
# No circles were found
# Novo frame
# Distância é: 323.7508698922039
# No circles were found
# Novo frame
# Distância é: 324.50210005146766
# No circles were found
# Novo frame
# Distância é: 329.95353137840607
# No circles were found
# Novo frame
# Distância é: 341.38640688703725
# No circles were found
# Novo frame
# Distância é: 343.83805575728496
# No circles were found
# Novo frame
# Distância é: 349.9455682327938
# No circles were found
# Novo frame
# Distância é: 343.88051538399134
# No circles were found
# Novo frame
# Distância é: 348.815424562849
# No circles were found
# Novo frame
# Distância é: 351.5225672260881
# No circles were found
# Novo frame
# Distância é: 351.8575913543767
# No circles were found
# Novo frame
# Distância é: 351.3808962276828
# No circles were found
# Novo frame
# Distância é: 348.14697821364166
# No circles were found
# Novo frame
# Distância é: 347.5755064161795
# No circles were found
# Novo frame
# Distância é: 348.3178668452659
# No circles were found
# Novo frame
# Distância é: 346.80519753239463
# No circles were found
# Novo frame
# Distância é: 349.9399740713171
# No circles were found
# Novo frame
# Distância é: 349.35964204001834
# No circles were found
# Novo frame
# Distância é: 350.5456981070243
# No circles were found
# Novo frame
# Distância é: 351.2733407532822
# No circles were found
# Novo frame
# Distância é: 344.25270932481453
# No circles were found
# Novo frame
# Distância é: 350.39397225852576
# No circles were found
# Novo frame
# Distância é: 349.78903304842464
# No circles were found
# Novo frame
# Distância é: 351.4885505590188
# No circles were found
# Novo frame
# Distância é: 353.19007592877085
# No circles were found
# Novo frame
# Distância é: 358.9468916107783
# No circles were found
# Novo frame
# Distância é: 368.3278253446299
# No circles were found
# Novo frame
# Distância é: 378.18094977873994
# No circles were found
# Novo frame
# Distância é: 388.07373217193646
# No circles were found
# Novo frame
# Distância é: 397.12397468577353
# No circles were found
# Novo frame
# Distância é: 396.77288790781733
# No circles were found
# Novo frame
# Distância é: 404.61523999301386
# No circles were found
# Novo frame
# Distância é: 414.72735823620985
# No circles were found
# Novo frame
# Distância é: 429.06070881462125
# No circles were found
# Novo frame
# Distância é: 432.2616483573538
# No circles were found
# Novo frame
# Distância é: 429.7428571696471
# No circles were found
# Novo frame
# Distância é: 438.1909090330079
# No circles were found
# Novo frame
# Distância é: 438.1909090330079
# No circles were found
# Novo frame
# Distância é: 439.99223859949944
# No circles were found
# Novo frame
# Distância é: 446.598432386922
# No circles were found
# Novo frame
# Distância é: 445.37097048017466
# No circles were found
# Novo frame
# Distância é: 450.7485386774772
# No circles were found
# Novo frame
# Distância é: 417.26463037544033
# No circles were found
# Novo frame
# Distância é: 391.686460865998
# No circles were found
# Novo frame
# Distância é: 374.4180692768191
# No circles were found
# Novo frame
# Distância é: 357.97883507951053
# No circles were found
# Novo frame
# Distância é: 347.24708854150373
# No circles were found
# Novo frame
# Distância é: 350.03511131904617
# No circles were found
# Novo frame
# Distância é: 365.89301103743406
# No circles were found
# Novo frame
# Distância é: 388.8159012437553
# No circles were found
# Novo frame
# Distância é: 427.2065096271626
# No circles were found
# Novo frame
# Distância é: 495.39694923382535
# No circles were found
# Novo frame
# Distância é: 629.9149124717677
# No circles were found
# Novo frame
# Distância é: 1027.919340589825
# No circles were found
# Novo frame
# Distância é: 9665.428547146785
# No circles were found
# Novo frame
# Distância é: 3221.809515715595
# No circles were found
# Novo frame
# Distância é: 1807.0244835719504
# No circles were found
# Novo frame
# Distância é: 1801.6566926403025
# No circles were found
# Novo frame
# Distância é: 1813.9969512111745
# No circles were found
# Novo frame
# Distância é: 1357.9844429269372
# No circles were found
# Novo frame
# Distância é: 1420.9519014636148
# No circles were found
# Novo frame
# Distância é: 1449.1075726553888
# No circles were found
# Novo frame
# Distância é: 1790.3135157057907
# No circles were found
# Novo frame
# Distância é: 2043.7528476530806
# No circles were found
# Novo frame
# Distância é: 2150.7893363422813
# No circles were found
# Novo frame
# Distância é: 2535.069750374089
# No circles were found
# Novo frame
# Distância é: 2854.7239196543696
# No circles were found
# Novo frame
# Distância é: 2438.765874193428
# No circles were found
# Novo frame
# Distância é: 2463.759791904002
# No circles were found
# Novo frame
# Distância é: 2756.752485060799
# No circles were found
# Novo frame
# Distância é: 2112.8535673277734
# No circles were found
# Novo frame
# Distância é: 1850.1119133842876
# No circles were found
# Novo frame
# Distância é: 1059.673767164855
# No circles were found
# Novo frame
# Distância é: 676.5940253949861
# No circles were found
# Novo frame
# Distância é: 541.7610612003692
# No circles were found
# Novo frame
# Distância é: 475.70298291790147
# No circles were found
# Novo frame
# Distância é: 427.0234254737746
# No circles were found
# Novo frame
# Distância é: 382.4460403819025
# No circles were found
# Novo frame
# Distância é: 339.81837110422066
# No circles were found
# Novo frame
# Distância é: 307.3010681308462
# No circles were found
# Novo frame
# Distância é: 279.9201211162867
# No circles were found
# Novo frame
# Distância é: 258.9200771405796
# No circles were found
# Novo frame
# Distância é: 241.77949729160804
# No circles were found
# Novo frame
# Distância é: 227.8750101873582
# No circles were found
# Novo frame
# Distância é: 217.357645531104
# No circles were found
# Novo frame
# Distância é: 207.49183458384343
# No circles were found
# Novo frame
# Distância é: 200.8746012346485
# No circles were found
# Novo frame
# Distância é: 196.96672927644522
# No circles were found
# Novo frame
# Distância é: 203.53249192857305
# No circles were found
# Novo frame
# Distância é: 205.9957029381271
# No circles were found
# Novo frame
# Distância é: 207.11851679762484
# No circles were found
# Novo frame
# Distância é: 205.87143709166892
# No circles were found
# Novo frame
# Distância é: 202.62832377914836
# No circles were found
# Novo frame
# Distância é: 202.21688649231322
# No circles were found
# Novo frame
# Distância é: 203.95424358055521
# No circles were found
# Novo frame
# Distância é: 200.97519446106202
# No circles were found
# Novo frame
# Distância é: 197.07355098085242
# No circles were found
# Novo frame
# Distância é: 192.60147132697847
# No circles were found
# Novo frame
# Distância é: 191.54237742954825
# No circles were found
# Novo frame
# Distância é: 191.45345572769122
# No circles were found
# Novo frame
# Distância é: 191.02161523121762
# No circles were found
# Novo frame
# Distância é: 193.46529412400665
# No circles were found
# Novo frame
# Distância é: 198.35077989086318
# No circles were found
# Novo frame
# Distância é: 200.83969365613484
# No circles were found
# Novo frame
# Distância é: 201.23531815058303
# No circles were found
# Novo frame
# Distância é: 205.91929270722696
# No circles were found
# Novo frame
# Distância é: 209.72795705795605
# No circles were found
# Novo frame
# Distância é: 214.91936074002575
# No circles were found
# Novo frame
# Distância é: 222.7575960820539
# No circles were found
# Novo frame
# Distância é: 231.7563991880644
# No circles were found
# Novo frame
# Distância é: 241.12350270582803
# No circles were found
# Novo frame
# Distância é: 259.61395657285533
# No circles were found
# Novo frame
# Distância é: 294.75602750585455
# No circles were found
# Novo frame
# Distância é: 347.2580208093151
# No circles were found
# Novo frame
# Distância é: 381.529268690862
# No circles were found
# Novo frame
# Distância é: 397.32852384002786
# No circles were found
# Novo frame
# Distância é: 413.7715608499577
# No circles were found
# Novo frame
# Distância é: 451.1195990788673
# No circles were found
# Novo frame
# Distância é: 500.7025349170035
# No circles were found
# Novo frame
# Distância é: 547.9902247995778
# No circles were found
# Novo frame
# Distância é: 590.8134225183378
# No circles were found
# Novo frame
# Distância é: 625.9396266601151
# No circles were found
# Novo frame
# Distância é: 683.0326504519641
# No circles were found
# Novo frame
# Distância é: 832.0931700024429
# No circles were found
# Novo frame
# Distância é: 1194.820613542637
# No circles were found
# Novo frame
# Distância é: 2220.253347689837
# No circles were found
# Novo frame
# Distância é: 2161.2555263087243
# No circles were found
# Novo frame
# Distância é: 1702.7921295143776
# No circles were found
# Novo frame
# Distância é: 1473.5461856050224
# No circles were found
# Novo frame
# Distância é: 1368.902754033317
# No circles were found
# Novo frame
# Distância é: 1259.8950858840306
# No circles were found
# Novo frame
# Distância é: 1132.0095362513225
# No circles were found
# Novo frame
# Distância é: 1021.0416709924737
# No circles were found
# Novo frame
# Distância é: 915.4928207331855
# No circles were found
# Novo frame
# Distância é: 819.3079317516676
# No circles were found
# Novo frame
# Distância é: 744.6237404959965
# No circles were found
# Novo frame
# Distância é: 684.3676776733903
# No circles were found
# Novo frame
# Distância é: 647.2803671207946
# No circles were found
# Novo frame
# Distância é: 623.9641441636453
# No circles were found
# Novo frame
# Distância é: 581.7390242764726
# No circles were found
# Novo frame
# Distância é: 537.9003843303691
# No circles were found
# Novo frame
# Distância é: 507.18417467255495
# No circles were found
# Novo frame
# Distância é: 484.1282660696314
# No circles were found
# Novo frame
# Distância é: 460.9601259460448
# No circles were found
# Novo frame
# Distância é: 447.636912684486
# No circles were found
# Novo frame
# Distância é: 440.54926153250796
# No circles were found
# Novo frame
# Distância é: 437.3148767512955
# No circles were found
# Novo frame
# Distância é: 442.22182025888407
# No circles were found
# Novo frame
# Distância é: 452.98874561483524
# No circles were found
# Novo frame
# Distância é: 466.2406020877925
# No circles were found
# Novo frame
# Distância é: 480.91659592488185
# No circles were found
# Novo frame
# Distância é: 504.17956264710625
# No circles were found
# Novo frame
# Distância é: 542.8854368018503
# No circles were found
# Novo frame
# Distância é: 587.8476473200874
# No circles were found
# Novo frame
# Distância é: 656.0214497897684
# No circles were found
# Novo frame
# Distância é: 743.9240830377171
# No circles were found
# Novo frame
# Distância é: 873.0618470965968
# No circles were found
# Novo frame
# Distância é: 1089.6345401941555
# No circles were found
# Novo frame
# Distância é: 1315.8927120957983
# No circles were found
# Novo frame
# Distância é: 1609.2701508839436
# No circles were found
# Novo frame
# Distância é: 2143.038718931445
# No circles were found
# Novo frame
# Distância é: 3230.576360535904
# No circles were found
# Novo frame
# Distância é: 5346.390098196123
# No circles were found
# Novo frame
# Distância é: 8501.09967248411
# No circles were found
# Novo frame
# Distância é: 7450.552813844356
# No circles were found
# Novo frame
# Distância é: 5513.504970121598
# No circles were found
# Novo frame
# Distância é: 8197.390330347223
# No circles were found
# Novo frame
# Distância é: 8057.253673722323
# No circles were found
# Novo frame
# Distância é: 3914.200234530676
# No circles were found
# Novo frame
# Distância é: 7859.903213924334
# No circles were found
# Novo frame
# Distância é: 7797.273504957429
# No circles were found
# Novo frame
# Distância é: 7924.066753759258
# No circles were found
# Novo frame
# Distância é: 5230.570078872856
# No circles were found
# Novo frame
# Distância é: 8932.899012685262
# No circles were found
# Novo frame
# Distância é: 6098.098437496566
# No circles were found
# Novo frame
# Distância é: 7618.001874547293
# No circles were found
# Novo frame
# Distância é: 9125.026347788049
# No circles were found
# Novo frame
# Distância é: 6635.19081224817
# No circles were found
# Novo frame
# Distância é: 9225.858429195387
# No circles were found
# Novo frame
# Distância é: 8126.4159180055385
# No circles were found
# Novo frame
# Distância é: 12137.419680475748
# No circles were found
# Novo frame
# Distância é: 10940.522252445264
# No circles were found
# Novo frame
# Distância é: 11299.322795341912
# No circles were found
# Novo frame
# Distância é: 10773.481569168442
# No circles were found
# Novo frame
# Distância é: 8582.45176217146
# No circles were found
# Novo frame
# Distância é: 15472.234948852734
# No circles were found
# Novo frame
# Distância é: 18660.217452206616
# No circles were found
# Novo frame
# Distância é: 15979.655542804003
# No circles were found
# Novo frame
# Distância é: 9330.108726103308
# No circles were found
# Novo frame
# Distância é: 9125.026347788049
# No circles were found
# Novo frame
# Distância é: 18660.217452206616
# No circles were found
# Novo frame
# Distância é: 18660.217452206616
# No circles were found
# Novo frame
# Distância é: 8841.277113630134
# No circles were found
# Novo frame
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-5d86cc250f1e> in <module>()
#      85     img = frame.copy()
#      86
# ---> 87     media, centro = identifica_cor(img)
#      88
#      89     #More drawing functions @ http://docs.opencv.org/2.4/modules/core/doc/drawing_functions.html
#
# <ipython-input-1-5d86cc250f1e> in identifica_cor(frame)
#      54             maior_contorno_area = area
#      55     #print(maior_contorno[0])
# ---> 56     distance = (((2009**2)*474.5)/maior_contorno_area)**(1/2)
#      57     print("Distância é: {0}".format(distance))
#      58
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ####
